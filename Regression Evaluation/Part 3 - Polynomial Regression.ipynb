# %%
from luwiji.poly_regression import illustration, demo

# %%
demo.data()

# %% [markdown]
# # Polynomial Regression

# %%
illustration.polynomial_regression

# %%
demo.polynomial_regression()
# Out:
# interactive(children=(ToggleButtons(description='Model', options=('Poly(1)', 'Poly(2)', 'Poly(3)', 'Poly(10)',…

# %%
demo.nonlinear()
# Out:
# interactive(children=(ToggleButtons(description='Model', options=('Poly(1)', 'Poly(2)', 'Poly(3)', 'Poly(10)',…

# %% [markdown]
# `Poly(3)` merupakan model yang paling simple yang memberikan test score terbaik. Jadi kita pilih `Poly(3)`

# %% [markdown]
# # Scikit-learn code

# %% [markdown]
# ```
# model = Pipeline([
#     ("poly", PolynomialFeatures(5)),
#     ("lr", LinearRegression())
# ])
# model.fit(X_train, y_train)
# ```

# %% [markdown]
# ![Screenshot%20%282938%29.png](attachment:Screenshot%20%282938%29.png)

# %% [markdown]
# ![Screenshot%20%282940%29.png](attachment:Screenshot%20%282940%29.png)
