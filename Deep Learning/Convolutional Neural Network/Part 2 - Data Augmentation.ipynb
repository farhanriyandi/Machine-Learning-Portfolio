# %%
from torchvision import transforms
from luwiji.cnn import illustration

# %% [markdown]
# # Data Augmentation
#
# augmentasi: Sedikit mengubah data asli
# - meningkatkan generality (mengurangi overfit)<br>
# - menambah data<br>
#
# **It is a best practice to perform data augmentation when possible.**

# %%
img = illustration.img
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x288>

# %% [markdown]
# ### Random Crop

# %%
test = transforms.Resize(250)
# test = transforms.CenterCrop(224)
test(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=335x250>

# %%
test = transforms.CenterCrop(min(64, original_width, original_height))

test(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 test = transforms.CenterCrop(min(64, original_width, original_height))
#       3 test(img)
#
# NameError: name 'original_width' is not defined

# %%
test = transforms.Resize(64)
# test = transforms.CenterCrop(224)
test(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=85x64>

# %%
crop = transforms.RandomCrop(256)
crop(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256>

# %%
greyscale = transforms.Grayscale(num_output_channels=3)
greyscale(img)
# Out:
# <PIL.Image.Image image mode=RGB size=386x288>

# %%
greyscale = transforms.Grayscale(num_output_channels=1)
greyscale(img)
# Out:
# <PIL.Image.Image image mode=L size=386x288>

# %% [markdown]
# ### Random Flip

# %%
hflip = transforms.RandomHorizontalFlip()
hflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %%
vflip = transforms.RandomVerticalFlip()
vflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %% [markdown]
# ### Random Rotation

# %%
rotate = transforms.RandomRotation(10)
rotate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %% [markdown]
# ### Random ResizedCrop

# %%
resize = transforms.Resize(224)
resize(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x224>

# %%
resize = transforms.RandomResizedCrop(224, scale=(0.8, 1.0))
resize(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=224x224>

# %%
resize = transforms.RandomResizedCrop(256, scale=(0.8, 1.0))
resize(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256>

# %% [markdown]
# ### Random Affine

# %%
translate = transforms.RandomAffine(0, translate=(0.3, 0.3))
translate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %%
shear = transforms.RandomAffine(0, shear=10)
shear(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %%
affine = transforms.RandomAffine(5, translate=(0.1, 0.1), shear=10)
affine(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %% [markdown]
# ### Color Jitter

# %%
brightness = transforms.ColorJitter(brightness=0.3)
brightness(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %%
contrast = transforms.ColorJitter(contrast=0.3)
contrast(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288>

# %% [markdown]
# # 1 Gambar seakan" menjadi banyak

# %%
import matplotlib.pyplot as plt
from luwiji.cnn import illustration

img = illustration.img

# %%
transform = transforms.Compose([
    transforms.RandomRotation(15),
    transforms.RandomResizedCrop((224, 224), scale=(0.7, 1)),
    transforms.ColorJitter((0.7, 1.3))
])

fig, axes = plt.subplots(5, 5, figsize=(15, 15))
fig.subplots_adjust(wspace=0.1, hspace=0.1)
for ax in axes.flatten():
    ax.imshow((img))
    ax.axis("off")

# %% [markdown]
# # Diskusi
#
# Apakah ada kasus dimana augmentasi tertentu tidak boleh dipakai?
