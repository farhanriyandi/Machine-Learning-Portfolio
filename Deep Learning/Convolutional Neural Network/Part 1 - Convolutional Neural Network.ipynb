# %%
from luwiji.cnn import illustration

# %% [markdown]
# ### The power combination in Neural Network ==> Feature Extraction

# %%
illustration.combination

# %% [markdown]
# ### Our main goal

# %%
illustration.goal

# %% [markdown]
# # Concept 1: Filter and Edge Detection

# %% [markdown]
# http://matlabtricks.com/post-5/3x3-convolution-kernels-with-online-demo

# %% [markdown]
# # Concept 2: Convolution

# %%
illustration.conv_ex1

# %%
illustration.conv_ex2

# %%
illustration.conv_ex3

# %%
illustration.conv_ex4

# %%
illustration.blur_avg

# %% [markdown]
# # Concept 3: Stride/Langkah

# %%
illustration.stride

# %% [markdown]
# Stride yang besar menyebabkan hasil konvolusi yang lebih kecil

# %% [markdown]
# # Concept 4: Padding/Sumpel

# %%
illustration.padding

# %% [markdown]
# Padding biasa digunakan untuk menjamin ukuran sama seperti ukuran semula

# %%
illustration.padding_same

# %% [markdown]
# # Quick Exercise

# %% [markdown]
# https://github.com/vdumoulin/conv_arithmetic

# %% [markdown]
# # Concept 5: Pooling

# %%
illustration.pooling

# %% [markdown]
# # Use them All -> Convolutional Neural Network

# %% [markdown]
# Video by Otavio Good ==> https://www.youtube.com/watch?v=Oqm9vsf_hvU<br>
# Shorter vid ==> https://www.youtube.com/watch?v=f0t-OCG79-U&t=2s

# %% [markdown]
# # Which Filter to use?

# %% [markdown]
# No, we won't choose. We simply train the filter.

# %% [markdown]
# # Advantage of CNN

# %% [markdown]
# ### parameter sharing => local connectivity

# %%
illustration.partial_con

# %% [markdown]
# ### contain spatial information => translation invariance

# %%
illustration.translation

# %% [markdown]
# # ANN vs CNN

# %%
illustration.nn_vs_cnn

# %% [markdown]
# # Feature Map Visualization
#
# Filtered image also known as feature map. Let's visualize the feature map to see how the filters performing.
#
# https://www.youtube.com/watch?v=AgkfIQ4IGaM
