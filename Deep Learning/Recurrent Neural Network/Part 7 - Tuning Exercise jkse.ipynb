# %%
from jcopdl.callback import set_config
import pandas as pd

# %%
# data = "damped_sine"
data = "jkse"

config = set_config({
    "input_size": 1,
    "seq_len": 5,
    "batch_size": 32,
    "output_size": 1,
    "hidden_size": 64,
    "num_layers": 2,
    "dropout": 0.2,
    "bidirectional": True, # True/False
    "cell_type": "gru" # rnn/gru/lstm
})

lr = 0.0005

# %% [markdown]
# # Jangan edit code di bawah ini

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
from torch import nn, optim
from jcopdl.callback import Callback
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader
from utils import data4pred, pred4pred

# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
device

class RNN(nn.Module):
    def __init__(self, cell_type, input_size, output_size, hidden_size, num_layers, dropout, bidirectional):
        super().__init__()
        
        if cell_type == "rnn":
            rnn_block = nn.RNN
        elif cell_type == "lstm":
            rnn_block = nn.LSTM
        elif cell_type == "gru":
            rnn_block = nn.GRU
        
        self.rnn = rnn_block(input_size, hidden_size, num_layers, dropout=dropout, bidirectional=bidirectional)
        
        if bidirectional:
            hidden_size = 2*hidden_size
            
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):        
        x, hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden
    
if data == "damped_sine":
    df = pd.read_csv("data/sine_new.csv", parse_dates=["Date"], index_col="Date")
    df.value = df.value.transform(lambda x: (x-x.mean())/x.std())
    col = "value"    
elif data == "jkse":
    df = pd.read_csv("data/jkse.csv", parse_dates=["Date"], index_col="Date")
    df = df[~df.price.isna()]
    df.price = df.price.transform(lambda x: (x-x.mean())/x.std())
    col = "price"

ts_train, ts_test = train_test_split(df, test_size=0.2, shuffle=False)

train_set = TimeSeriesDataset(ts_train, col, config.seq_len)
trainloader = DataLoader(train_set, batch_size=config.batch_size)

test_set = TimeSeriesDataset(ts_test, col, config.seq_len)
testloader = DataLoader(test_set, batch_size=config.batch_size)

model = RNN(config.cell_type, config.input_size, config.output_size, config.hidden_size, 
            config.num_layers, config.dropout, config.bidirectional).to(device)
criterion = nn.MSELoss(reduction='mean')
optimizer = optim.AdamW(model.parameters(), lr=lr)
callback = Callback(model, config, outdir=f'model/{data}/')

from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
        
# Forecast
train_forecast_set = TimeSeriesDataset(ts_train, col, 1)
trainforecastloader = DataLoader(train_forecast_set)

test_forecast_set = TimeSeriesDataset(ts_test, col, 1)
testforecastloader = DataLoader(test_forecast_set)

plt.figure(figsize=(15, 15))
    
plt.subplot(311)
data4pred(model, train_forecast_set, trainforecastloader, device)
plt.title("Train")

plt.subplot(312)
data4pred(model, test_forecast_set, testforecastloader, device)
plt.title("Test")

plt.subplot(313)
pred4pred(model, test_forecast_set, testforecastloader, device, n_prior=400, n_forecast=100)
plt.title("Test");
# Out:
# (N, S, F): (387, 5, 1)
# Note: last 4 data excluded
#
# (N, S, F): (97, 5, 1)
# Note: last 0 data excluded
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     1
# Train_cost  = 0.8421 | Test_cost  = 1.2875 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     2
# Train_cost  = 0.4068 | Test_cost  = 0.5843 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     3
# Train_cost  = 0.1427 | Test_cost  = 0.0956 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     4
# Train_cost  = 0.0351 | Test_cost  = 0.0840 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     5
# Train_cost  = 0.0330 | Test_cost  = 0.0605 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     6
# Train_cost  = 0.0230 | Test_cost  = 0.0626 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0605
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     7
# Train_cost  = 0.0223 | Test_cost  = 0.0578 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     8
# Train_cost  = 0.0208 | Test_cost  = 0.0560 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch     9
# Train_cost  = 0.0191 | Test_cost  = 0.0557 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    10
# Train_cost  = 0.0185 | Test_cost  = 0.0543 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    11
# Train_cost  = 0.0180 | Test_cost  = 0.0519 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    12
# Train_cost  = 0.0175 | Test_cost  = 0.0506 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    13
# Train_cost  = 0.0171 | Test_cost  = 0.0498 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    14
# Train_cost  = 0.0168 | Test_cost  = 0.0480 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    15
# Train_cost  = 0.0158 | Test_cost  = 0.0468 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    16
# Train_cost  = 0.0157 | Test_cost  = 0.0458 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    17
# Train_cost  = 0.0151 | Test_cost  = 0.0432 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    18
# Train_cost  = 0.0150 | Test_cost  = 0.0434 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0432
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    19
# Train_cost  = 0.0147 | Test_cost  = 0.0406 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    20
# Train_cost  = 0.0140 | Test_cost  = 0.0398 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    21
# Train_cost  = 0.0138 | Test_cost  = 0.0379 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    22
# Train_cost  = 0.0138 | Test_cost  = 0.0397 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0379
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    23
# Train_cost  = 0.0133 | Test_cost  = 0.0350 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    24
# Train_cost  = 0.0134 | Test_cost  = 0.0378 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0350
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    25
# Train_cost  = 0.0131 | Test_cost  = 0.0331 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    26
# Train_cost  = 0.0134 | Test_cost  = 0.0357 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0331
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    27
# Train_cost  = 0.0133 | Test_cost  = 0.0299 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    28
# Train_cost  = 0.0130 | Test_cost  = 0.0396 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0299
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    29
# Train_cost  = 0.0155 | Test_cost  = 0.0278 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    30
# Train_cost  = 0.0175 | Test_cost  = 0.0474 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0278
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    31
# Train_cost  = 0.0245 | Test_cost  = 0.0276 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    32
# Train_cost  = 0.0257 | Test_cost  = 0.0495 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0276
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    33
# Train_cost  = 0.0350 | Test_cost  = 0.0253 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    34
# Train_cost  = 0.0242 | Test_cost  = 0.0365 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0253
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    35
# Train_cost  = 0.0233 | Test_cost  = 0.0239 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    36
# Train_cost  = 0.0151 | Test_cost  = 0.0276 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0239
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    37
# Train_cost  = 0.0130 | Test_cost  = 0.0235 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    38
# Train_cost  = 0.0113 | Test_cost  = 0.0269 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0235
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    39
# Train_cost  = 0.0109 | Test_cost  = 0.0229 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    40
# Train_cost  = 0.0102 | Test_cost  = 0.0263 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0229
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    41
# Train_cost  = 0.0102 | Test_cost  = 0.0227 |
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    42
# Train_cost  = 0.0095 | Test_cost  = 0.0270 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0227
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    43
# Train_cost  = 0.0096 | Test_cost  = 0.0227 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0227
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    44
# Train_cost  = 0.0090 | Test_cost  = 0.0250 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0227
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    45
# Train_cost  = 0.0086 | Test_cost  = 0.0253 |
# ==> EarlyStop patience =  4 | Best test_cost: 0.0227
# Train:   0%|          | 0/13 [00:00<?, ?it/s]
# Test:   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch    46
# Train_cost  = 0.0089 | Test_cost  = 0.0241 |
# ==> EarlyStop patience =  5 | Best test_cost: 0.0227
# ==> Execute Early Stopping at epoch: 46 | Best test_cost: 0.0227
# ==> Best model is saved at model/jkse/
# (N, S, F): (1939, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (485, 1, 1)
# Note: last 0 data excluded

# %% [markdown]
# Note:
# * yang pertama harus di analisa NSF
# * jika error zigzag masalahnya learning rate

# %% [markdown]
# * contoh error zigzag
#
# ![image.png](attachment:image.png)
#
# - learning rate dikecilkan
# - tambahkan dropout sedikit

# %% [markdown]
# lihat NSF nya dulu,
#
# auto regresi = regresi terhadap diri sendiri
# yang harus dicek pertama adalah auto korelasinya,
# korelasi terhadap diri sendiri dimasa lalu.
#
# jika Seq length = 1. sama saja seperti nn biasa karena memory
# masa lalunya tidak dibawa kedepan.
#
# Jika errornya zigzag berarti learning rate perlu dikecilkan.
