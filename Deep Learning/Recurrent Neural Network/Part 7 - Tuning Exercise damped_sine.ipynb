# %%
from jcopdl.callback import set_config
import pandas as pd

# %% [markdown]
# damped sine
#
# sine = sinus atau gelombang
#
# damped = melemah
# damped sine = gelombang yang melemah
#
# ![image.png](attachment:image.png)
#
#
# gambar yang bawah adalah contoh dari damped sine

# %%
data = "damped_sine"
# data = "jkse"

config = set_config({
    "input_size": 1,
    "seq_len": 2,
    "batch_size": 32,
    "output_size": 1,
    "hidden_size": 256,
    "num_layers": 2,
    "dropout": 0.2,
    "bidirectional": False, # True/False
    "cell_type": "gru" # rnn/gru/lstm
})

lr = 0.0005

# %% [markdown]
# # Jangan edit code di bawah ini

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
from torch import nn, optim
from jcopdl.callback import Callback
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader
from utils import data4pred, pred4pred

# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")
device

class RNN(nn.Module):
    def __init__(self, cell_type, input_size, output_size, hidden_size, num_layers, dropout, bidirectional):
        super().__init__()
        
        if cell_type == "rnn":
            rnn_block = nn.RNN
        elif cell_type == "lstm":
            rnn_block = nn.LSTM
        elif cell_type == "gru":
            rnn_block = nn.GRU
        
        self.rnn = rnn_block(input_size, hidden_size, num_layers, dropout=dropout, bidirectional=bidirectional)
        
        if bidirectional:
            hidden_size = 2*hidden_size
            
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):        
        x, hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden
    
if data == "damped_sine":
    df = pd.read_csv("data/sine_new.csv", parse_dates=["Date"], index_col="Date")
    df.value = df.value.transform(lambda x: (x-x.mean())/x.std())
    col = "value"    
elif data == "jkse":
    df = pd.read_csv("data/jkse.csv", parse_dates=["Date"], index_col="Date")
    df = df[~df.price.isna()]
    df.price = df.price.transform(lambda x: (x-x.mean())/x.std())
    col = "price"

ts_train, ts_test = train_test_split(df, test_size=0.2, shuffle=False)

train_set = TimeSeriesDataset(ts_train, col, config.seq_len)
trainloader = DataLoader(train_set, batch_size=config.batch_size)

test_set = TimeSeriesDataset(ts_test, col, config.seq_len)
testloader = DataLoader(test_set, batch_size=config.batch_size)

model = RNN(config.cell_type, config.input_size, config.output_size, config.hidden_size, 
            config.num_layers, config.dropout, config.bidirectional).to(device)
criterion = nn.MSELoss(reduction='mean')
optimizer = optim.AdamW(model.parameters(), lr=lr)
callback = Callback(model, config, outdir=f'model/{data}/')

from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
        
# Forecast
train_forecast_set = TimeSeriesDataset(ts_train, col, 1)
trainforecastloader = DataLoader(train_forecast_set)

test_forecast_set = TimeSeriesDataset(ts_test, col, 1)
testforecastloader = DataLoader(test_forecast_set)

plt.figure(figsize=(15, 15))
    
plt.subplot(311)
data4pred(model, train_forecast_set, trainforecastloader, device)
plt.title("Train")

plt.subplot(312)
data4pred(model, test_forecast_set, testforecastloader, device)
plt.title("Test")

plt.subplot(313)
pred4pred(model, test_forecast_set, testforecastloader, device, n_prior=400, n_forecast=100)
plt.title("Test");
# Out:
# (N, S, F): (969, 2, 1)
# Note: last 1 data excluded
#
# (N, S, F): (242, 2, 1)
# Note: last 1 data excluded
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     1
# Train_cost  = 0.7506 | Test_cost  = 0.0031 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     2
# Train_cost  = 0.0972 | Test_cost  = 0.0022 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     3
# Train_cost  = 0.0769 | Test_cost  = 0.0018 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     4
# Train_cost  = 0.0650 | Test_cost  = 0.0015 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     5
# Train_cost  = 0.0549 | Test_cost  = 0.0013 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     6
# Train_cost  = 0.0474 | Test_cost  = 0.0012 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     7
# Train_cost  = 0.0427 | Test_cost  = 0.0012 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     8
# Train_cost  = 0.0377 | Test_cost  = 0.0010 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch     9
# Train_cost  = 0.0342 | Test_cost  = 0.0009 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    10
# Train_cost  = 0.0318 | Test_cost  = 0.0009 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    11
# Train_cost  = 0.0293 | Test_cost  = 0.0009 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0009
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    12
# Train_cost  = 0.0279 | Test_cost  = 0.0008 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    13
# Train_cost  = 0.0242 | Test_cost  = 0.0008 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0008
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    14
# Train_cost  = 0.0222 | Test_cost  = 0.0007 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    15
# Train_cost  = 0.0187 | Test_cost  = 0.0006 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    16
# Train_cost  = 0.0167 | Test_cost  = 0.0005 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    17
# Train_cost  = 0.0152 | Test_cost  = 0.0006 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0005
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    18
# Train_cost  = 0.0136 | Test_cost  = 0.0005 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    19
# Train_cost  = 0.0126 | Test_cost  = 0.0005 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0005
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    20
# Train_cost  = 0.0101 | Test_cost  = 0.0002 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    21
# Train_cost  = 0.0080 | Test_cost  = 0.0002 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    22
# Train_cost  = 0.0070 | Test_cost  = 0.0002 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    23
# Train_cost  = 0.0065 | Test_cost  = 0.0001 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    24
# Train_cost  = 0.0055 | Test_cost  = 0.0001 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    25
# Train_cost  = 0.0049 | Test_cost  = 0.0001 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    26
# Train_cost  = 0.0042 | Test_cost  = 0.0001 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    27
# Train_cost  = 0.0037 | Test_cost  = 0.0001 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0001
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    28
# Train_cost  = 0.0036 | Test_cost  = 0.0000 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    29
# Train_cost  = 0.0033 | Test_cost  = 0.0000 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    30
# Train_cost  = 0.0032 | Test_cost  = 0.0000 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    31
# Train_cost  = 0.0031 | Test_cost  = 0.0000 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    32
# Train_cost  = 0.0029 | Test_cost  = 0.0000 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    33
# Train_cost  = 0.0026 | Test_cost  = 0.0000 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    34
# Train_cost  = 0.0028 | Test_cost  = 0.0000 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    35
# Train_cost  = 0.0024 | Test_cost  = 0.0000 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    36
# Train_cost  = 0.0025 | Test_cost  = 0.0000 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    37
# Train_cost  = 0.0024 | Test_cost  = 0.0000 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    38
# Train_cost  = 0.0030 | Test_cost  = 0.0001 |
# ==> EarlyStop patience =  4 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    39
# Train_cost  = 0.0021 | Test_cost  = 0.0000 |
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    40
# Train_cost  = 0.0030 | Test_cost  = 0.0001 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    41
# Train_cost  = 0.0030 | Test_cost  = 0.0001 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    42
# Train_cost  = 0.0037 | Test_cost  = 0.0002 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    43
# Train_cost  = 0.0040 | Test_cost  = 0.0002 |
# ==> EarlyStop patience =  4 | Best test_cost: 0.0000
# Train:   0%|          | 0/31 [00:00<?, ?it/s]
# Test:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch    44
# Train_cost  = 0.0044 | Test_cost  = 0.0001 |
# ==> EarlyStop patience =  5 | Best test_cost: 0.0000
# ==> Execute Early Stopping at epoch: 44 | Best test_cost: 0.0000
# ==> Best model is saved at model/damped_sine/
# (N, S, F): (1939, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (485, 1, 1)
# Note: last 0 data excluded

# %% [markdown]
# Note:
# * yang pertama harus di analisa NSF
# * jika error zigzag masalahnya learning rate

# %% [markdown]
# * contoh error zigzag
#
# ![image.png](attachment:image.png)
