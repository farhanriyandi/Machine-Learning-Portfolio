# %%
from luwiji.logistic_regression import illustration, demo

# %% [markdown]
# # Classification with Regression

# %%
demo.logistic_regression()
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a', max=5.0, step=0.5), FloatSlider(value=0.0, descr…

# %% [markdown]
# # Better loss for classification

# %% [markdown]
# **MSE loss menghasilkan plateau** sehingga lebih baik kita pakai **Mean Cross Entropy Loss (MCE)**

# %%
demo.loss_curve()
# Out:
# interactive(children=(ToggleButtons(description='loss', options=('MSE', 'MCE'), value='MSE'), Output()), _dom_…

# %% [markdown]
# # Akan lebih terlihat di loss plane

# %%
demo.loss_plane()
# Out:
# interactive(children=(ToggleButtons(description='loss', options=('MSE', 'MCE'), value='MSE'), Output()), _dom_…

# %% [markdown]
# # Code in Scikit-learn
#
# ```
# model = LogisticRegression()
# model.fit(X_train, y_train)
# ```

# %% [markdown]
# # Probability

# %% [markdown]
# Karena sigmoid berkisar dari 0 sampai 1, maka prediksinya dapat dipakai probability

# %%
illustration.predict_proba

# %% [markdown]
# Untuk prediksinya, maka kita perlu menentukan threshold

# %%
demo.threshold()
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a', max=5.0, min=0.5, step=0.5), IntSlider(value=0, …

# %% [markdown]
# ![Screenshot%20%283044%29.png](attachment:Screenshot%20%283044%29.png)

# %% [markdown]
# ### MSE
#
# ![Screenshot%20%283045%29.png](attachment:Screenshot%20%283045%29.png)

# %% [markdown]
# ### MCE
#
# ![Screenshot%20%283046%29.png](attachment:Screenshot%20%283046%29.png)

# %% [markdown]
# selama kompit rekamnya pakai gradient base
